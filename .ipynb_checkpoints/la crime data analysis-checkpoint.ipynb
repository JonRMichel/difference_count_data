# %%
import numpy as np
import pandas as pd

# %%
crime_data = pd.read_excel('C:/Users/michelj8/Documents/GitHub/integer_valued_ts/813_crimes.xlsx')

# %%
crime_data.head()
# Out:
#        DR_NO  Date Rptd   DATE OCC  TIME OCC  AREA    AREA NAME  Rpt Dist No  \
# 0  190505845 2019-02-11 2019-02-05       730      5      Harbor          563
# 1  190212708 2019-06-07 2019-06-03       320      2     Rampart          275
# 2  191715992 2019-09-26 2019-09-25      1730     17  Devonshire         1777
# 3  191716137 2019-09-27 2019-09-26      1340     17  Devonshire         1737
# 4  191914524 2019-08-06 2019-08-06      1200     19     Mission         1935
#
#    Part 1-2  Crm Cd                     Crm Cd Desc  ... Status  Status Desc  \
# 0         2     813  CHILD ANNOYING (17YRS & UNDER)  ...     IC  Invest Cont
# 1         2     813  CHILD ANNOYING (17YRS & UNDER)  ...     IC  Invest Cont
# 2         2     813  CHILD ANNOYING (17YRS & UNDER)  ...     IC  Invest Cont
# 3         2     813  CHILD ANNOYING (17YRS & UNDER)  ...     AO  Adult Other
# 4         2     813  CHILD ANNOYING (17YRS & UNDER)  ...     IC  Invest Cont
#
#   Crm Cd 1 Crm Cd 2  Crm Cd 3 Crm Cd 4  \
# 0      813      NaN       NaN      NaN
# 1      813      NaN       NaN      NaN
# 2      813      NaN       NaN      NaN
# 3      813      NaN       NaN      NaN
# 4      813      NaN       NaN      NaN
#
#                                    LOCATION Cross Street      LAT       LON
# 0           13TH                         ST     CABRILLO  33.7324 -118.2946
# 1   1600 W  11TH                         ST          NaN  34.0506 -118.2769
# 2   9800    WOODLEY                      AV          NaN  34.2422 -118.4897
# 3  16500    CHATSWORTH                   ST          NaN  34.2703 -118.4959
# 4  15100 S  BRAND                        BL          NaN  34.2752 -118.4603
#
# [5 rows x 28 columns]

# %%
ts_df = crime_data.groupby(['DATE OCC']).count()[['DR_NO']].reset_index()
ts_df['year-month'] = ts_df['DATE OCC'].apply(lambda s: str(s)[0:7])

ts_df = ts_df.groupby('year-month').sum()
ts_df.columns = ['Y']

# %%
ts_df['Y'].plot()

# %%
from statsmodels.tsa.arima_model import ARMA
model = ARMA(ts_df, (1,0)).fit()
model.params
# Out:
# C:\Users\michelj8\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# const      42.912993
# ar.L1.Y     0.424788
# dtype: float64

# %%
model.resid.plot()

# %%
ts_df['delta'] = ts_df['Y'].diff(1)
ts_df['abs_delta'] = np.abs(ts_df['delta'])

# %%
model = ARMA(ts_df['delta'].dropna(), (1,0)).fit()
print(model.params)
model.resid.plot()
# Out:
# C:\Users\michelj8\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# const         -0.366381
# ar.L1.delta   -0.461628
# dtype: float64

# %%
model = ARMA(ts_df['abs_delta'].dropna(), (1,0)).fit()
print(model.params)
model.resid.plot()
# Out:
# C:\Users\michelj8\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# const              11.875853
# ar.L1.abs_delta     0.219364
# dtype: float64

# %%
ts_df['abs_delta'].plot()

# %%
def sgn(x):
    if x == 0:
        return 0
    if x>0:
        return 1
    if x<0:
        return -1

ts_df['sign_dif'] = ts_df['delta'].apply(lambda s: sgn(s))
ts_df['sign_dif'].plot()

# %%
model = ARMA(ts_df['sign_dif'].dropna(), (1,0)).fit()
print(model.params)
# Out:
# const            -0.022155
# ar.L1.sign_dif   -0.228382
# dtype: float64
# C:\Users\michelj8\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'

# %%
ts_df['sign_dif'].rolling(window = 12).mean().plot()

# %%
ts_df['delta_lag'] = ts_df['delta'].shift(1)

# %%
ts_df.plot.scatter(x='delta_lag' ,y='abs_delta')

# %%
ts_df['sign_dif_lag'] = ts_df['sign_dif'].shift(1)
ts_df.plot.scatter(x='sign_dif_lag',y='abs_delta')

# %%
print (ts_df[['sign_dif_lag','abs_delta']].groupby('sign_dif_lag').mean(), ts_df[['sign_dif_lag','abs_delta']].groupby('sign_dif_lag').std() )
# Out:
#               abs_delta
# sign_dif_lag
# -1.0          10.586207
#  0.0          13.750000
#  1.0          13.089286               abs_delta
# sign_dif_lag
# -1.0           8.408505
#  0.0          14.728091
#  1.0          11.045817

# %% [markdown]
# # Estimation

# %%
def ingarch_filter(w,a,b, con,r,p):
    dates = ts_df.index
    mu_est = [ts_df.loc[dates[1],'abs_delta'] ]
    p_est = [.5]
    
    for date in dates[2:]:
        y = ts_df.loc[date,'abs_delta']
        s = sgn(ts_df.loc[date,'delta'])
        mu_est.append(w + a*y + b*mu_est[-1])
        p_est.append(con + p*s + r*p_est[-1])
    
    filter_df = pd.DataFrame({'mu':mu_est,'prob':p_est})
    filter_df['year-month'] = dates[1:]
    return filter_df.set_index('year-month')

# %%
ingarch_filter(.1,.2,.5, .5,.1,.2)['prob'].plot()

# %%
ts_df.head()
# Out:
#              Y  delta  abs_delta  sign_dif  delta_lag  sign_dif_lag
# year-month
# 2010-01     71    NaN        NaN       NaN        NaN           NaN
# 2010-02     59  -12.0       12.0      -1.0        NaN           NaN
# 2010-03     63    4.0        4.0       1.0      -12.0          -1.0
# 2010-04     47  -16.0       16.0      -1.0        4.0           1.0
# 2010-05     58   11.0       11.0       1.0      -16.0          -1.0
